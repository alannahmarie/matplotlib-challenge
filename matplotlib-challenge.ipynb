# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata, study_results, how="left", on="Mouse ID")

# Display the data table for preview
combined_data_df.set_index('Mouse ID')
# Out:
#          Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# k403         Ramicane  Male          21          16          0
# k403         Ramicane  Male          21          16          5
# k403         Ramicane  Male          21          16         10
# k403         Ramicane  Male          21          16         15
# k403         Ramicane  Male          21          16         20
# ...               ...   ...         ...         ...        ...
# z969         Naftisol  Male           9          30         25
# z969         Naftisol  Male           9          30         30
# z969         Naftisol  Male           9          30         35
# z969         Naftisol  Male           9          30         40
# z969         Naftisol  Male           9          30         45
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# k403               45.000000                 0
# k403               38.825898                 0
# k403               35.014271                 1
# k403               34.223992                 1
# k403               32.997729                 1
# ...                      ...               ...
# z969               63.145652                 2
# z969               65.841013                 3
# z969               69.176246                 4
# z969               70.314904                 4
# z969               73.867845                 4
#
# [1893 rows x 7 columns]

# %%
# Checking the number of mice.
number_of_mice = combined_data_df.loc[:,"Mouse ID"].unique()
len(number_of_mice)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = combined_data_df.duplicated(subset=["Mouse ID", "Timepoint"], keep=False).value_counts()
duplicates
# Out:
# False    1883
# True       10
# dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID. 
combined_data_df.loc[combined_data_df.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data_df = combined_data_df.loc[combined_data_df["Mouse ID"] != "g989"]

# %%
clean_data_df.set_index("Mouse ID")
# Out:
#          Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# k403         Ramicane  Male          21          16          0
# k403         Ramicane  Male          21          16          5
# k403         Ramicane  Male          21          16         10
# k403         Ramicane  Male          21          16         15
# k403         Ramicane  Male          21          16         20
# ...               ...   ...         ...         ...        ...
# z969         Naftisol  Male           9          30         25
# z969         Naftisol  Male           9          30         30
# z969         Naftisol  Male           9          30         35
# z969         Naftisol  Male           9          30         40
# z969         Naftisol  Male           9          30         45
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# k403               45.000000                 0
# k403               38.825898                 0
# k403               35.014271                 1
# k403               34.223992                 1
# k403               32.997729                 1
# ...                      ...               ...
# z969               63.145652                 2
# z969               65.841013                 3
# z969               69.176246                 4
# z969               70.314904                 4
# z969               73.867845                 4
#
# [1880 rows x 7 columns]

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice_clean = clean_data_df.loc[:,"Mouse ID"].unique()
len(number_of_mice_clean)
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
drug_tumor_table = clean_data_df[["Drug Regimen", "Tumor Volume (mm3)"]]

mean = drug_tumor_table.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median = drug_tumor_table.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
variance = drug_tumor_table.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
std_dev = drug_tumor_table.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
std_error = drug_tumor_table.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

summary_table = pd.DataFrame({"mean": mean,
                                "median": median,
                                "var": variance, 
                                "std": std_dev,
                                "sem": std_error})
summary_table.style.set_caption("Tumor Volume(mm3)")
# Out:
# <style  type="text/css" >
# </style><table id="T_0a916488_668d_11eb_b05a_acde48001122" ><caption>Tumor Volume(mm3)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >median</th>        <th class="col_heading level0 col2" >var</th>        <th class="col_heading level0 col3" >std</th>        <th class="col_heading level0 col4" >sem</th>    </tr>    <tr>        <th class="index_name level0" >Drug Regimen</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row0" class="row_heading level0 row0" >Capomulin</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row0_col0" class="data row0 col0" >40.675741</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row0_col1" class="data row0 col1" >41.557809</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row0_col2" class="data row0 col2" >24.947764</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row0_col3" class="data row0 col3" >4.994774</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row0_col4" class="data row0 col4" >0.329346</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row1" class="row_heading level0 row1" >Ceftamin</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row1_col0" class="data row1 col0" >52.591172</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row1_col1" class="data row1 col1" >51.776157</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row1_col2" class="data row1 col2" >39.290177</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row1_col3" class="data row1 col3" >6.268188</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row1_col4" class="data row1 col4" >0.469821</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row2" class="row_heading level0 row2" >Infubinol</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row2_col0" class="data row2 col0" >52.884795</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row2_col1" class="data row2 col1" >51.820584</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row2_col2" class="data row2 col2" >43.128684</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row2_col3" class="data row2 col3" >6.567243</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row2_col4" class="data row2 col4" >0.492236</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row3" class="row_heading level0 row3" >Ketapril</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row3_col0" class="data row3 col0" >55.235638</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row3_col1" class="data row3 col1" >53.698743</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row3_col2" class="data row3 col2" >68.553577</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row3_col3" class="data row3 col3" >8.279709</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row3_col4" class="data row3 col4" >0.603860</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row4" class="row_heading level0 row4" >Naftisol</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row4_col0" class="data row4 col0" >54.331565</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row4_col1" class="data row4 col1" >52.509285</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row4_col2" class="data row4 col2" >66.173479</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row4_col3" class="data row4 col3" >8.134708</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row4_col4" class="data row4 col4" >0.596466</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row5" class="row_heading level0 row5" >Placebo</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row5_col0" class="data row5 col0" >54.033581</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row5_col1" class="data row5 col1" >52.288934</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row5_col2" class="data row5 col2" >61.168083</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row5_col3" class="data row5 col3" >7.821003</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row5_col4" class="data row5 col4" >0.581331</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row6" class="row_heading level0 row6" >Propriva</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row6_col0" class="data row6 col0" >52.320930</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row6_col1" class="data row6 col1" >50.446266</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row6_col2" class="data row6 col2" >43.852013</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row6_col3" class="data row6 col3" >6.622085</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row6_col4" class="data row6 col4" >0.544332</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row7" class="row_heading level0 row7" >Ramicane</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row7_col0" class="data row7 col0" >40.216745</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row7_col1" class="data row7 col1" >40.673236</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row7_col2" class="data row7 col2" >23.486704</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row7_col3" class="data row7 col3" >4.846308</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row7_col4" class="data row7 col4" >0.320955</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row8" class="row_heading level0 row8" >Stelasyn</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row8_col0" class="data row8 col0" >54.233149</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row8_col1" class="data row8 col1" >52.431737</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row8_col2" class="data row8 col2" >59.450562</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row8_col3" class="data row8 col3" >7.710419</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row8_col4" class="data row8 col4" >0.573111</td>
#             </tr>
#             <tr>
#                         <th id="T_0a916488_668d_11eb_b05a_acde48001122level0_row9" class="row_heading level0 row9" >Zoniferol</th>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row9_col0" class="data row9 col0" >53.236507</td>
#                         <td id="T_0a916488_668d_11eb_b05a_acde48001122row9_col1" class="data row9 col1" >51.818479</td>
#                         <td id="T_0a9

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

aggregate_summary_table = drug_tumor_table.groupby('Drug Regimen').aggregate(['mean', np.median, np.var, np.std, 'sem'])

aggregate_summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
bar_chart_data = drug_tumor_table.groupby("Drug Regimen").count()
bar_chart_data.rename(columns = {"Tumor Volume (mm3)":"# of Measurements",}, inplace = True) 
bar_chart_data
# Out:
#               # of Measurements
# Drug Regimen
# Capomulin                   230
# Ceftamin                    178
# Infubinol                   178
# Ketapril                    188
# Naftisol                    186
# Placebo                     181
# Propriva                    148
# Ramicane                    228
# Stelasyn                    181
# Zoniferol                   182

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
bar_chart_data.plot(kind="bar", color='dodgerblue', figsize=(15,6), rot=30,\
                    title="Total Number of Tumor Measurements Per Drug Regimen")
plt.ylabel("Total Number of Tumor Measurements")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
bar_chart_data.reset_index(inplace=True)
drug_regimen = bar_chart_data["Drug Regimen"]
measurements = bar_chart_data["# of Measurements"]

number_of_drugs = np.arange(len(drug_regimen))

plt.figure(figsize=(15,6))
plt.bar(number_of_drugs, measurements, width=.55,color="dodgerblue")
plt.title("Total Number of Tumor Measurements Per Drug Regimen")
plt.legend(["# of Measurements"], loc=1)
plt.xticks(ticks=number_of_drugs, labels=drug_regimen, rotation=30)
plt.xlabel("Drug Regimen")
plt.ylabel("Total Number of Tumor Measurements")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_data = pd.DataFrame(clean_data_df[["Sex", "Mouse ID"]])
gender_data = gender_data.drop_duplicates(subset="Mouse ID", keep="first")
gender_data = gender_data.groupby("Sex").count()

gender_data.plot(kind="pie", subplots=True, colors=["peachpuff", "gainsboro"], autopct='%1.1f%%', figsize=(11,11), startangle=270, title="Male versus Female Mice", textprops={'fontsize': 14})
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_data = gender_data.reset_index()

# Labels for the sections of our pie chart
labels = ["Male", "Female"]

# The values of each section of the pie chart
male_mice = gender_data["Mouse ID"][0]
female_mice = gender_data["Mouse ID"][1]

sizes = [male_mice,  female_mice]

# The colors of each section of the pie chart
colors = ["peachpuff", "gainsboro"]


plt.figure(figsize=[11, 11])
plt.pie(sizes, labels=labels, colors=colors,autopct="%1.1f%%", startangle=90, textprops={'fontsize': 14})
plt.title("Male versus Female Mice")
plt.legend()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
quartile_df = clean_data_df.set_index("Mouse ID")
capomulin = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Capomulin"]
capomulin = capomulin.groupby("Mouse ID")["Timepoint"].max()
ramicane = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Ramicane"]    
ramicane = ramicane.groupby("Mouse ID")["Timepoint"].max()

# Start by getting the last (greatest) timepoint for each mouse
# max_timepoint = clean_data_df.groupby("Mouse ID")["Timepoint"].max()
# max_timepoint
# clean_data_df = combined_data_df.loc[combined_data_df["Mouse ID"] != "g989"]
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

time_tumor_table = clean_data_df[["Tumor Volume (mm3)", "Timepoint", "Drug Regimen", "Mouse ID"]]
time_tumor_table = time_tumor_table[time_tumor_table["Drug Regimen"] == "Capomulin"]
line_plot_data = time_tumor_table.set_index("Drug Regimen")
line_plot_data.groupby("Mouse ID").max()

x_axis = line_plot_data["Timepoint"]
y_axis = line_plot_data["Tumor Volume (mm3)"]

plt.(x_axis, y_axis)
# Out:
#   File "<ipython-input-60-3c7ecaf7f684>", line 11
#     plt.(x_axis, y_axis)
#         ^
# SyntaxError: invalid syntax

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
